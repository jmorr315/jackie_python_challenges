# %%
def find_max(num):
    value = 0
    for i in num:
        if i > value:
            value = i
    return value        
num_list = [1,30,44,29,105,30,2,9,20]  
print(find_max(num_list))
# Out:
# 105
